# %%
from pyproj import Proj, transform
import numpy as np
import pandas as pd
import re

data=pd.read_csv("hospital_수정01.csv",encoding='CP949')
data.head()
# Out:
#    번호  개방자치단체코드  영업상태명         소재지전화                         도로명전체주소  도로명우편번호  \
# 0   1   5340000  영업/정상  055-851-5400      경상남도 사천시 사천읍 옥산로 127, 3~7층  52517.0
# 1   2   5340000  영업/정상  055-852-2250           경상남도 사천시 사천읍 구암두문로 74  52517.0
# 2   3   5340000  영업/정상  055-834-2345     경상남도 사천시 각산로 86 (서동, 미진예식장)  52556.0
# 3   4   5380000  영업/정상  055-389-1234         경상남도 양산시 모래들1길 91 (주진동)  50521.0
# 4   5   5410000  영업/정상  055-806-8600  경상남도 창녕군 고암면 상대2길 16, 더케이서드에이지  50315.0
#
#                     사업장명      좌표정보(x)      좌표정보(y)       의료기관종별명  \
# 0  의료법인 행복한의료재단 사천중앙요양병원  299970.3318  176114.7080  요양병원(일반요양병원)
# 1                 사천동희병원  299722.4204  177131.7783            병원
# 2     의료법인 삼포의료재단 현대요양병원  297272.3901  159579.1491  요양병원(일반요양병원)
# 3                   양산병원  394946.0000  213423.0000    요양병원(정신병원)
# 4                프라임요양병원  337000.3444  232019.5924  요양병원(일반요양병원)
#
#                                               진료과목내용  \
# ...

# %%
pattern=re.compile('[0-9]+,')
for i in range(5):
    address=data['도로명전체주소'][i]
    result=pattern.findall(address)
    print(result,address,len(result))
    # if result!=[]:
    #     arr=address.split(result)
    #     print(arr)
    # else:
    #     print("없음")
# Out:
# ['127,'] 경상남도 사천시 사천읍 옥산로 127, 3~7층 1
# [] 경상남도 사천시 사천읍 구암두문로 74 0
# [] 경상남도 사천시 각산로 86 (서동, 미진예식장) 0
# [] 경상남도 양산시 모래들1길 91 (주진동) 0
# ['16,'] 경상남도 창녕군 고암면 상대2길 16, 더케이서드에이지 1
